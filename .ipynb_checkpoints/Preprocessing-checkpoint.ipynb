# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Data-Preprocessing" data-toc-modified-id="Data-Preprocessing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Preprocessing</a></span></li><li><span><a href="#Extracting-tweets-from-SQL-database" data-toc-modified-id="Extracting-tweets-from-SQL-database-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Extracting tweets from SQL database</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Word2vec" data-toc-modified-id="Word2vec-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Word2vec</a></span></li></ul></li></ul></li><li><span><a href="#Topic-Modeling" data-toc-modified-id="Topic-Modeling-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Topic Modeling</a></span></li></ul></div>

# %% [markdown]
# # Libraries
#
#     The following Libraries were used in the development of this project:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import spacy
import nltk
import pyodbc
from nltk.tokenize import RegexpTokenizer, WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import string
from string import punctuation
import collections
from collections import Counter
import json 

import warnings
warnings.filterwarnings("ignore")
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %% [markdown]
# # Data Preprocessing
#
# The data preprocessing consist of different stages:

# %%
import nltk 


'''Natural Language Processing libraries'''
import nltk 
import gensim
import regex as re
import spacy
from spacy.lang.en import English
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from gensim.models import Word2Vec
import gensim.downloader as api
import re, string, unicodedata
from nltk.stem import LancasterStemmer, WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize
from gensim.models import FastText
from gensim.models import Word2Vec



class Document:
    """ Retrieve the narratives from the DataFrame and respectively
        store and pre-process it. 
        
        :param df: DataFrame including the reports and the predictor variable. 
        
        
        :ivar data: Stores the DataFrame.
        :ivar text: Stores the narratives as string.
        :ivar corpus: Stores the pre-processed text.
    """
    
    
    def __init__(self, df):
        self.data = df
        self.text = df["text"].astype(str)
        self.textPreProcessing()
        
        
    def remove_non_ascii(self, words):
        """Remove non-ASCII characters from list of tokenized words
        
        :param words:  List of words to be transformed when removing non_ascii characters.
        
        :return new_words: List of words after the transformation of removed non_ascii characters.
        
        """
        new_words = []
        for word in words:
            new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
            new_words.append(new_word)
        return new_words


    def remove_punctuation(self, words):
        """Remove punctuation from list of tokenized words
        
        :param words:  List of words that will get remove their punctuations, if any. 
        
        :return new_words: List of transformed words.
        
        
        """
        new_words = []
        for word in words:
            new_word = re.sub(r'[^\w\s]', '', word)
            if new_word != '':
                new_words.append(new_word)
        return new_words


    def stem_words(self, words):
        """Stem words in list of tokenized words
        
        :param words:  List of words to be processed. 
        
        :return new_words: List of the received words respective stems.
        
        
        """
        
        stemmer = LancasterStemmer()
        stems = []
        for word in words:
            stem = stemmer.stem(word)
            stems.append(stem)
        return stems
    
    def lemmatize_verbs(self, words):
        """Lemmatize verbs in list of tokenized words
        
        :param words:  List of words to be processed. 
        
        :return new_words: List of the received words respective lemmas.
        
        """
        
        lemmatizer = WordNetLemmatizer()
        lemmas = []
        for word in words:
            lemma = lemmatizer.lemmatize(word, pos='v')
            lemmas.append(lemma)
        return lemmas
    
    
    
    def remove_stopwords(self, words):
        """Remove common words that have no meaning or importance in the sentence.

        :param words:  List of words to be processed and get stop words removed.. 

        :return new_words: List of words with the stop words already removed."""
            
        
        stop_words = set(stopwords.words('spanish')) 
        stop_words1 = set(stopwords.words('english')) 


        
        for word in stop_words:
            if word in words:
                words.remove(word)
                
        for word in stop_words1:
            if word in words:
                words.remove(word)
                
        return words


    
    def normalize(self, words):
        words = self.remove_non_ascii(words)
        words = self.remove_stopwords(words)
        words = self.remove_punctuation(words)
        words = self.lemmatize_verbs(words)
        return words
    
    
    def textPreProcessing(self):
        """Pre-process the text, normalize and clean it.
        The function stores the cleaned text in the self.data
        attribute. """
        p.set_options(p.OPT.URL,p.OPT.MENTION,p.OPT.HASHTAG,p.OPT.RESERVED,p.OPT.SMILEY,p.OPT.NUMBER)


        clean_text = []

        for narrative in self.text:
            sentence = p.clean(narrative)
            #sentence = re.sub('RT @[\w_]+:', '', sentence)

            #sentence = re.sub(r'https?:\/\/.*[\r\n]*', '', sentence)
            sentence = word_tokenize(sentence)
            sentence = self.normalize(sentence)
                
                
            clean_text.append(sentence)
            
            
                    
        print(len(self.text), len(clean_text))
        self.data["clean_text"] = clean_text
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def concatTweets(table):
    tweets = ''
    c = 0
    for row in df.tweets:
        if(c == 0):
            c+= 1
            tweets = pd.DataFrame(json.loads(row))
        else:
            tweets = pd.concat([tweets, pd.DataFrame(json.loads(row))], axis=0, ignore_index=True)
    
    
    return tweets

# %% [markdown]
# # Extracting tweets from SQL database

# %%
server = 'sqldatamining.database.windows.net'
database = 'SNA'
username = 'UserAdmin'
password = 'Machomen123'   
driver= '{ODBC Driver 17 for SQL Server}'

cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=sqldatamining.database.windows.net,1433', user='UserAdmin' , password='Machomen123', database='SNA')

# %%
cursor = cnxn.cursor()

# %%
rows = cursor.execute("SELECT * from dbo.Users1").fetchmany(10)

# %%
df = pd.DataFrame((tuple(t) for t in rows), columns=['id',
 'author',
 'created_at',
 'location',
 'description',
 'verified',
 'followers',
 'following',
 'favourites_count',
 'statuses_count',
 'lang',
 'tweets',
 'following_json',
 'followers_json'])

# %%
df.head()
# Out:
#                     id           author          created_at  \
# 0           2284857094  themoonisironic 2014-01-16 01:10:33
# 1            834324620        bbelita23 2012-09-19 23:21:48
# 2            175521394     Stormfocus18 2010-08-06 21:03:08
# 3           1685491040   CoraimaINegron 2013-08-20 10:48:59
# 4  1388202983964520449  Personn34091581 2021-04-30 18:46:05
#
#                        location  \
# 0  ‘97 // they/them // ????????
# 1              spooky town, PR
# 2           Puerto Rico_Island
# 3                   Puerto Rico
# 4                   Costa brava
#
#                                          description  verified  followers  \
# 0  where there is hope, there are trials // art: ...     False        101
# 1                  just put it out into the universe     False        670
# 2  Loving #MewGulf and #KristSingto, amante de la...     False        199
# 3  “El karma te lo devolverá todo, excepto a la m...     False         64
# 4                                                        False          0
#
#    following  favourites_count  statuses_count  lang  \
# 0        516            121166           36377  None
# 1        443             33428           92917  None
# 2        187              6497           38945  None
# 3        203              1336            1565  None
# 4          2                 9               7  None
#
#                                               tweets  \
# 0  [{"id": 1356030533780824069, "created_at": "20...
# 1  [{"id": 1356026926134140928, "created_at": "20...
# 2                                                 []
# 3  [{"id": 1283388114661244934, "created_at": "20...
# 4                                                 []
#
#                                       following_json  \
# 0  [{"id": 1387079251476815875, "author": "rikuno...
# 1  [{"id": 2513536418, "author": "Kvn_Astacio", "...
# 2  [{"id": 1387677517822054400, "author": "tinest...
# 3  [{"id": 299932350, "author": "DMcIntyreWWE", "...
# 4  [{"id": 560803492, "author": "UrbanLePharaon",...
#
#                                       followers_json
# 0  [{"id": 1384297303129825284, "author": "bts123...
# 1  [{"id": 1289669319526420482, "author": "keviin...
# 2  [{"id": 1387677517822054400, "author": "tinest...
# 3  [{"id": 713749428935462916, "author": "DavidRo...
# 4                                                 []

# %%
x = concatTweets(df)

x.head(100)

#x.groupby(by=["user"]).head()
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                      id           created_at  \
# 0   1356030533780824069  2021-02-01T00:04:07
# 1   1355996223753383939  2021-01-31T21:47:47
# 2   1355995462784978944  2021-01-31T21:44:46
# 3   1355995461820137472  2021-01-31T21:44:45
# 4   1355991939976454146  2021-01-31T21:30:46
# ..                  ...                  ...
# 95  1355174454620512260  2021-01-29T15:22:22
# 96  1355172899494256642  2021-01-29T15:16:11
# 97  1355157553706115078  2021-01-29T14:15:13
# 98  1355157022065438720  2021-01-29T14:13:06
# 99  1355156645450575874  2021-01-29T14:11:36
#
#                                                  text coordinates   geo  \
# 0   RT @geheichou: Childe I told you to stop\n#Gen...        None  None
# 1   i’m also obsessed with a curse stemming from l...        None  None
# 2   i also really like yuta - he’s sweet but terri...        None  None
# 3   kk, finished jjk 0\nit was really interesting ...        None  None
# 4   @hinosreis no, jujutsu kaisen!! it’s off next ...        None  None
# ..                                                ...         ...   ...
# 95  pls, bts and halsey's first performance of boy...        None  None
# 96    https://t.co/7LQYTjHEEF https://t.co/o9MctFrsFp        None  None
# 97       baby is mastiff main im gonna cry!!! nerd!!!        None  None
# 98                baby, que?? https://t.co/Be5Rhk02Rq        None  None
# 99  ahhh kuzu already has a nickname for mafu im g...        None  None
#
#                user  retweet_count  favorite_count
# 0   themoonisironic           4929               0
# 1   themoonisironic              0               0
# 2   themoonisironic              0               0
# 3   themoonisironic              0               0
# 4   themoonisironic              0               1
# ..              ...            ...             ...
# 95  themoonisironic              0               0
# 96  themoonisironic              0               1
# 97  themoonisironic              0               0
# 98  themoonisironic              0               1
# 99  themoonisironic              0               0
#
# [100 rows x 8 columns]

# %%
import preprocessor as p
p.set_options(p.OPT.URL,p.OPT.MENTION,p.OPT.HASHTAG,p.OPT.RESERVED,p.OPT.SMILEY,p.OPT.NUMBER)
p.clean('Preprocessor í is #awesome 👍 https://github.com/s/preprocessor')
# Out:
# 'Preprocessor í is 👍'

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('punkt')


texto = pd.DataFrame(tuits, columns=["text"])
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\afabi/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\afabi/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\afabi/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
nltk.download('stopwords')
nltk.download('wordnet')
documento = Document(texto)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\afabi/nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to C:\Users\afabi/nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-972918190e87> in <module>
#       1 nltk.download('stopwords')
#       2 nltk.download('wordnet')
# ----> 3 documento = Document(texto)
#
# <ipython-input-33-cfc285272681> in __init__(self, df)
#      36         self.data = df
#      37         self.text = df["text"].astype(str)
# ---> 38         self.textPreProcessing()
#      39
#      40
#
# <ipython-input-33-cfc285272681> in textPreProcessing(self)
#     137         The function stores the cleaned text in the self.data
#     138         attribute. """
# --> 139         p.set_options(p.OPT.URL,p.OPT.MENTION,p.OPT.HASHTAG,p.OPT.RESERVED,p.OPT.SMILEY,p.OPT.NUMBER)
#     140
#     141
#
# AttributeError: module 'preprocessor' has no attribute 'set_options'

# %%
documento.data.head()
# Out:
#                                                 text  \
# 0                   Nada más cierto! 🤦🏻‍♀️🤦🏻‍♀️🤦🏻‍♀️
# 1  Llamen a mi jefe diganle que la lluvia no me d...
# 2                                                  :
# 3                              : , , Pescao! Pescao!
# 4  Así está bien o todavía no estas tan sorprendi...
#
#                                           clean_text
# 0                                [Nada, mas, cierto]
# 1  [Llamen, jefe, diganle, lluvia, deja, ir, trab...
# 2                                                 []
# 3                                   [Pescao, Pescao]
# 4  [Asi, bien, todavia, tan, sorprendido, El, gol...

# %% [markdown]
# ### Word2vec

# %%
model = Word2Vec(documento.data["clean_text"], min_count=0, workers=20, window=2,  alpha=0.02, hs=1)

# %%
my_dict = dict({})
for idx, key in enumerate(model.wv.key_to_index):
    my_dict[key] = model.wv[key]

# %%
vectores = []
for a in documento.data.clean_text:
    t  = []
    for word in a:
        try:
            t.append(my_dict[word])
        except:
            continue
    
    vectores.append(t)
        
documento.data["vectorized_text"] = vectores
documento.data.tail()
# Out:
#                                                   text  \
# 113  : El ajusta la magnitud a , en el límite de pr...
# 114  : “ Van a seguir ocurriendo eventos fuertes. H...
# 115                         : Casa colapsada en Yauco.
# 116  : “Las réplicas podrían ser de magnitud mayor ...
# 117  : PRELIMINAR -01-06 :58:03 No hay Aviso, Adver...
#
#                                             clean_text  \
# 113  [El, ajusta, magnitud, limite, producir, tsunami]
# 114  [Van, seguir, ocurriendo, eventos, fuertes, Ha...
# 115                           [Casa, colapsada, Yauco]
# 116  [Las, replicas, podrian, ser, magnitud, mayor,...
# 117  [PRELIMINAR, 06, 5803, No, Aviso, Advertencia,...
#
#                                        vectorized_text
# 113  [[-0.017272485, 0.008652826, 0.007515971, 0.00...
# 114  [[-0.0027897793, -0.0016228552, -0.007687815, ...
# 115  [[0.008535036, 0.013252284, 0.00035941493, 0.0...
# 116  [[0.0029013832, -0.0027108788, -0.0015446608, ...
# 117  [[-0.0127012255, 0.0040803654, 0.009027934, -0...

# %%
df.tail()
# Out:
#                     id           author          created_at     location  \
# 5           1685491040   CoraimaINegron 2013-08-20 10:48:59  Puerto Rico
# 6  1388202983964520449  Personn34091581 2021-04-30 18:46:05  Costa brava
# 7   908687401123553280  rsantanafonseca 2017-09-15 13:42:13  COPU, UPRRP
# 8  1346688657365889024  SJCiudadCapital 2021-01-06 05:23:04
# 9            521836439       Angelicv_G 2012-03-12 01:12:16  Puerto Rico
#
#                                          description  verified  followers  \
# 5  “El karma te lo devolverá todo, excepto a la m...     False         64
# 6                                                        False          0
# 7  19 (+3) | ?????? | Pop culture enthusiast, soc...     False        891
# 8  Cuenta Oficial de la Ciudad Capital de Puerto ...     False       2915
# 9                     UT • yo no sé que poner aquí??     False        962
#
#    following  favourites_count  statuses_count  lang  \
# 5        203              1336            1565  None
# 6          2                 9               7  None
# 7        620            121676          124488  None
# 8        183               291            1157  None
# 9        519            115665          130883  None
#
#                                               tweets  \
# 5  [{"id": 1283388114661244934, "created_at": "20...
# 6                                                 []
# 7                                                 []
# 8  [{"id": 1355954464436473856, "created_at": "20...
# 9  [{"id": 1356041673227313154, "created_at": "20...
#
#                                       following_json  \
# 5  [{"id": 299932350, "author": "DMcIntyreWWE", "...
# 6  [{"id": 560803492, "author": "UrbanLePharaon",...
# 7  [{"id": 755882683, "author": "_vidalysrms", "c...
# 8  [{"id": 1309256724830969857, "author": "estefa...
# 9  [{"id": 1192074658994180096, "author": "Nsnili...
#
#                                       followers_json
# 5  [{"id": 713749428935462916, "author": "DavidRo...
# 6                                                 []
# 7  [{"id": 1344047685716815872, "author": "LeQuee...
# 8  [{"id": 1271152649304518657, "author": "JCruz_...
# 9  [{"id": 1383464766283280389, "author": "geegee...

# %%
c = 0
for x in df.tweets:
    tweets = pd.DataFrame(json.loads(x))
    c+=1 
    if(c==2):
        break
    

    
    
z = Document(tweets)


textos  = []
for a in z.data.clean_text.astype(str):
    for x in a:
        textos.append(a)
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 719 719

# %%
z.data.head()
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                     id           created_at  \
# 0  1356026926134140928  2021-01-31T23:49:47
# 1  1355947293153894400  2021-01-31T18:33:21
# 2  1355947277949530116  2021-01-31T18:33:18
# 3  1355912548630081542  2021-01-31T16:15:17
# 4  1355912278726631430  2021-01-31T16:14:13
#
#                                                 text coordinates   geo  \
# 0                    yikes 😬 https://t.co/pp9mcK3zhL        None  None
# 1  RT @CcNeiko: I need Giveon , Frank Ocean &amp;...        None  None
# 2  RT @TheMonai: Your secret is always safe with ...        None  None
# 3          no pido mucho solo un apartamento en NY 😔        None  None
# 4  RT @shaistadeen: outta sight but on your mind....        None  None
#
#         user  retweet_count  favorite_count  \
# 0  bbelita23              0               0
# 1  bbelita23          11227               0
# 2  bbelita23           5591               0
# 3  bbelita23              0               2
# 4  bbelita23          13997               0
#
#                                           clean_text
# 0                                            [yikes]
# 1  [I, need, Giveon, Frank, Ocean, amp, Brent, Fa...
# 2   [Your, secret, always, safe, cause, ima, forget]
# 3                      [pido, solo, apartamento, NY]
# 4                               [outta, sight, mind]

# %% [markdown]
# # Topic Modeling

# %%
def userSubSets(tweets, users):
    user = ''
    for instance in tweets:
        if(user != instance.user):
            user = instance.user 
            actual_user =  tweets['user']==user
            user_subset = tweets[actual_user]
            topicModeling()
        else:
            continue
            
            
def topicModeling(user_subset):

# %%
# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel


# Plotting tools
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
id2word = corpora.Dictionary(z.data.clean_text)

# Create Corpus
texts = z.data.clean_text

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=5, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
print(lda_model.print_topics())
# Out:
# [(0, '0.022*"que" + 0.018*"los" + 0.017*"s" + 0.012*"ano" + 0.011*"for" + 0.010*"y" + 0.010*"with" + 0.010*"mio" + 0.009*"bad" + 0.009*"amo"'), (1, '0.026*"you" + 0.019*"No" + 0.019*"if" + 0.016*"t" + 0.016*"we" + 0.015*"on" + 0.014*"don" + 0.014*"mas" + 0.012*"m" + 0.012*"I"'), (2, '0.041*"the" + 0.038*"this" + 0.032*"be" + 0.023*"to" + 0.018*"love" + 0.018*"my" + 0.017*"mood" + 0.016*"I" + 0.016*"claim" + 0.013*"it"'), (3, '0.021*"you" + 0.018*"be" + 0.018*"to" + 0.018*"do" + 0.017*"I" + 0.016*"when" + 0.011*"Frank" + 0.011*"Ocean" + 0.011*"a" + 0.011*"q"'), (4, '0.021*"recibir" + 0.018*"in" + 0.018*"solo" + 0.016*"si" + 0.016*"i" + 0.015*"Yo" + 0.014*"so" + 0.012*"necesita" + 0.011*"menos" + 0.011*"Dios"')]
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
lda_model.get_topics()[5]
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-39-9f5208f3b627> in <module>
# ----> 1 lda_model.get_topics()[5]
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
pyLDAvis.enable_notebook()
vis = gensimvis.prepare(lda_model, corpus, id2word)
vis
# Out:
# /usr/local/lib/python3.9/site-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.126004  0.094526       1        1  21.899446
# 4     -0.198367  0.066284       2        1  21.896521
# 3     -0.001912 -0.185583       3        1  19.960156
# 1      0.038494 -0.001149       4        1  19.031201
# 0      0.035780  0.025922       5        1  17.212676, topic_info=       Term       Freq      Total Category  logprob  loglift
# 5         I  34.000000  34.000000  Default  30.0000  30.0000
# 42     love  22.000000  22.000000  Default  29.0000  29.0000
# 137     que  20.000000  20.000000  Default  28.0000  28.0000
# 1726  claim  14.000000  14.000000  Default  27.0000  27.0000
# 935     los  15.000000  15.000000  Default  26.0000  26.0000
# ...     ...        ...        ...      ...      ...      ...
# 1700  Girls   1.915179   2.462405   Topic5  -5.6305   1.5082
# 1701    guy   1.915179   2.462405   Topic5  -5.6305   1.5082
# 1702  sleep   1.915179   2.462405   Topic5  -5.6305   1.5082
# 1703   zone   1.915179   2.462405   Topic5  -5.6305   1.5082
# 803      en   2.377364   3.196787   Topic5  -5.4143   1.4634
#
# [192 rows x 6 columns], token_table=      Topic      Freq   Term
# term
# 1478      5  0.738114
# 583       1  0.185664      A
# 583       3  0.742656      A
# 1725      4  0.902131    Asi
# 534       3  0.943928   Dios
# ...     ...       ...    ...
# 293       4  0.840526   want
# 428       1  0.777816  woman
# 1173      1  0.941177   year
# 294       4  0.927333    you
# 1703      5  0.812214   zone
#
# [168 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[3, 5, 4, 2, 1])

# %%
word2vec_model.wv.key_to_index
# Out:
# {'de': 0,
#  'No': 1,
#  'a': 2,
#  'Aviso': 3,
#  'Bayamon': 4,
#  'Nuevo': 5,
#  'Barrio': 6,
#  'El': 7,
#  'la': 8,
#  'magnitud': 9,
#  'Ml': 10,
#  'Sentido': 11,
#  'Km': 12,
#  'Prof': 13,
#  'Mag': 14,
#  'PRELIMINAR': 15,
#  'Max': 16,
#  'Puerto': 17,
#  'Rico': 18,
#  'Int': 19,
#  'temblor': 20,
#  'PR': 21,
#  'enero2020': 22,
#  'PM': 23,
#  'que': 24,
#  'mas': 25,
#  'tsunami': 26,
#  'be': 27,
#  'sabado': 28,
#  'luz': 29,
#  'servicio': 30,
#  'hoy': 31,
#  'La': 32,
#  'Gracias': 33,
#  'los': 34,
#  'Wanda': 35,
#  'Hoy': 36,
#  'mayor': 37,
#  'mejor': 38,
#  'ser': 39,
#  'el': 40,
#  'vez': 41,
#  'Que': 42,
#  'Mayaguez': 43,
#  'gente': 44,
#  'fuerte': 45,
#  'ver': 46,
#  'si': 47,
#  'l': 48,
#  'Mas': 49,
#  'cada': 50,
#  'ir': 51,
#  'chicharra': 52,
#  'con': 53,
#  'preliminar': 54,
#  'Islas': 55,
#  'Advertencia': 56,
#  'Vigilancia': 57,
#  'no': 58,
#  'Los': 59,
#  'ACTUALIZADA': 60,
#  'temblores': 61,
#  'pandemia': 62,
#  'Lo': 63,
#  'Enero': 64,
#  'tan': 65,
#  'espero': 66,
#  'isla': 67,
#  'Hola': 68,
#  'cierto': 69,
#  'Pescao': 70,
#  'bien': 71,
#  'vi': 72,
#  'NO': 73,
#  'entrada': 74,
#  've': 75,
#  'pm': 76,
#  'pico': 77,
#  'TEMBLOR': 78,
#  'IV': 79,
#  'solamente': 80,
#  'malo': 81,
#  'risa': 82,
#  'muriendo': 83,
#  'dia': 84,
#  'Molinelli': 85,
#  'va': 86,
#  'quedense': 87,
#  'seguridad': 88,
#  'por': 89,
#  'mia': 90,
#  'sus': 91,
#  'Jajajajaja': 92,
#  'Un': 93,
#  'pa': 94,
#  'Yauco': 95,
#  'PTWC': 96,
#  'dias': 97,
#  '0236': 98,
#  'V': 99,
#  'Ponce': 100,
#  'Adverten': 101,
#  'Temblor': 102,
#  'danos': 103,
#  'Es': 104,
#  'duermo': 105,
#  'I': 106,
#  'don': 107,
#  'slip': 108,
#  'tudey': 109,
#  'Virgenes': 110,
#  'M': 111,
#  'Y': 112,
#  'base': 113,
#  'estadounidenses': 114,
#  'casa': 115,
#  'consiencia': 116,
#  'viene': 117,
#  'Tomen': 118,
#  'A': 119,
#  'vamos': 120,
#  'dicen': 121,
#  'nunca': 122,
#  'ayer': 123,
#  'Jose': 124,
#  'manana': 125,
#  'Mi': 126,
#  'En': 127,
#  'principal': 128,
#  'un': 129,
#  'Dos': 130,
#  'las': 131,
#  'pediatra': 132,
#  'San': 133,
#  'luego': 134,
#  'empleados': 135,
#  'supermercados': 136,
#  'farmacias': 137,
#  'seguir': 138,
#  'Hagamos': 139,
#  'gracias': 140,
#  'noche': 141,
#  'trafico': 142,
#  'Ayuda': 143,
#  'profesional': 144,
#  'salud': 145,
#  'seria': 146}
